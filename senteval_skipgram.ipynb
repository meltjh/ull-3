# %%
# Copyright (c) 2017-present, Facebook, Inc.
# All rights reserved.
#
# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
#
#  The senteval_example.ipynb, modified to work with for our skip-gram models.

from __future__ import absolute_import, division, unicode_literals

import sys
import numpy as np
import logging
import sklearn
import examples.data as data
import pickle

# Set PATHs
# path to senteval
PATH_TO_SENTEVAL = ''
# path to the NLP datasets 
PATH_TO_DATA = 'data'
# info about the model
model_info = "_300_5_20_0.025_0.001_2_5"
# path to skipgram embeddings
PATH_TO_VEC = 'skipgram_data_trained/word_vectors/wordvec{}.txt'.format(model_info)
# path to word2id
PATH_TO_ID = 'skipgram_data_trained/word2id/word2id{}.txt'.format(model_info)

# import SentEval
sys.path.insert(0, PATH_TO_SENTEVAL)
import senteval

def prepare(params, samples):
    with open(PATH_TO_ID, 'rb') as f:
        params.word2id = pickle.load(f)

    # load skipgram/word2vec format 
    params.word_vec = data.get_wordvec(PATH_TO_VEC, params.word2id)
    # dimensionality of skipgram embeddings
    params.wvec_dim = 300
    return

def batcher(params, batch):
    """
    Use the average of word embeddings as a sentence representation.
    Each batch consists of one vector for sentence.
    Here you can process each sentence of the batch, 
    or a complete batch (you may need masking for that).
    
    """
    # if a sentence is empty dot is set to be the only token
    # you can change it into NULL dependening in your model
    batch = [sent if sent != [] else ['.'] for sent in batch]
    embeddings = []

    for sent in batch:
        sentvec = []
        # the format of a sentence is a lists of words (tokenized and lowercased)
        for word in sent:
            if word in params.word_vec:
                # [number of words, embedding dimensionality]
                sentvec.append(params.word_vec[word])
        if not sentvec:
            vec = np.zeros(params.wvec_dim)
            # [number of words, embedding dimensionality]
            sentvec.append(vec)
        # average of word embeddings for sentence representation
        # [embedding dimansionality]
        sentvec = np.mean(sentvec, 0)
        embeddings.append(sentvec)
    # [batch size, embedding dimensionality]
    embeddings = np.vstack(embeddings)
    return embeddings


# Set params for SentEval
# we use logistic regression (usepytorch: Fasle) and kfold 10
# In this dictionary you can add extra information that you model needs for initialization
# for example the path to a dictionary of indices, of hyper parameters
# this dictionary is passed to the batched and the prepare fucntions
params_senteval = {'task_path': PATH_TO_DATA, 'usepytorch': False, 'kfold': 10}
# this is the config for the NN classifier but we are going to use scikit-learn logistic regression with 10 kfold
# usepytorch = False 
#params_senteval['classifier'] = {'nhid': 0, 'optim': 'rmsprop', 'batch_size': 128,
#                                 'tenacity': 3, 'epoch_size': 2}

# Set up logger
logging.basicConfig(format='%(asctime)s : %(message)s', level=logging.DEBUG)

if __name__ == "__main__":
    se = senteval.engine.SE(params_senteval, batcher, prepare)
    
    # here you define the NLP taks that your embedding model is going to be evaluated
    # in (https://arxiv.org/abs/1802.05883) we use the following :
    # SICKRelatedness (Sick-R) needs torch cuda to work (even when using logistic regression), 
    # but STS14 (semantic textual similarity) is a similar type of semantic task
    transfer_tasks = ['MR', 'CR', 'MPQA', 'SUBJ', 'SST2', 'TREC',
                      'MRPC', 'SICKEntailment', 'STS14']
    # senteval prints the results and returns a dictionary with the scores
    results = se.eval(transfer_tasks)
    print(results)
# Out:
# 2018-05-31 19:13:20,471 : ***** Transfer task : MR *****
#
#
# 2018-05-31 19:13:26,690 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:13:26,712 : Generating sentence embeddings
# 2018-05-31 19:13:27,447 : Generated sentence embeddings
# 2018-05-31 19:13:27,449 : Training sklearn-LogReg with (inner) 10-fold cross-validation
# 2018-05-31 19:13:57,338 : Best param found at split 1: l2reg = 0.25                 with score 70.93
# 2018-05-31 19:14:26,094 : Best param found at split 2: l2reg = 0.25                 with score 70.8
# 2018-05-31 19:14:54,239 : Best param found at split 3: l2reg = 0.5                 with score 71.29
# 2018-05-31 19:15:21,462 : Best param found at split 4: l2reg = 0.25                 with score 70.84
# 2018-05-31 19:15:49,255 : Best param found at split 5: l2reg = 0.25                 with score 71.25
# 2018-05-31 19:16:17,648 : Best param found at split 6: l2reg = 0.25                 with score 71.22
# 2018-05-31 19:16:45,619 : Best param found at split 7: l2reg = 0.5                 with score 70.94
# 2018-05-31 19:17:13,796 : Best param found at split 8: l2reg = 0.25                 with score 70.72
# 2018-05-31 19:17:42,178 : Best param found at split 9: l2reg = 0.25                 with score 70.96
# 2018-05-31 19:18:10,192 : Best param found at split 10: l2reg = 0.5                 with score 71.07
# 2018-05-31 19:18:10,672 : Dev acc : 71.0 Test acc : 70.91
#
# 2018-05-31 19:18:10,676 : ***** Transfer task : CR *****
#
#
# 2018-05-31 19:18:16,166 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:18:16,533 : Generating sentence embeddings
# 2018-05-31 19:18:16,842 : Generated sentence embeddings
# 2018-05-31 19:18:16,843 : Training sklearn-LogReg with (inner) 10-fold cross-validation
# 2018-05-31 19:18:26,395 : Best param found at split 1: l2reg = 1                 with score 75.86
# 2018-05-31 19:18:35,822 : Best param found at split 2: l2reg = 0.5                 with score 75.89
# 2018-05-31 19:18:45,186 : Best param found at split 3: l2reg = 0.5                 with score 75.57
# 2018-05-31 19:18:54,746 : Best param found at split 4: l2reg = 1                 with score 76.07
# 2018-05-31 19:19:04,274 : Best param found at split 5: l2reg = 0.5                 with score 75.19
# 2018-05-31 19:19:13,553 : Best param found at split 6: l2reg = 0.5                 with score 75.18
# 2018-05-31 19:19:23,062 : Best param found at split 7: l2reg = 0.5                 with score 75.51
# 2018-05-31 19:19:32,582 : Best param found at split 8: l2reg = 1                 with score 75.69
# 2018-05-31 19:19:41,934 : Best param found at split 9: l2reg = 0.5                 with score 75.72
# 2018-05-31 19:19:51,493 : Best param found at split 10: l2reg = 1                 with score 75.58
# 2018-05-31 19:19:51,672 : Dev acc : 75.63 Test acc : 75.55
#
# 2018-05-31 19:19:51,674 : ***** Transfer task : MPQA *****
#
#
# 2018-05-31 19:19:56,742 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:19:57,016 : Generating sentence embeddings
# 2018-05-31 19:19:57,359 : Generated sentence embeddings
# 2018-05-31 19:19:57,361 : Training sklearn-LogReg with (inner) 10-fold cross-validation
# 2018-05-31 19:20:22,793 : Best param found at split 1: l2reg = 0.25                 with score 85.06
# 2018-05-31 19:20:49,496 : Best param found at split 2: l2reg = 0.25                 with score 85.53
# 2018-05-31 19:21:14,921 : Best param found at split 3: l2reg = 0.25                 with score 85.24
# 2018-05-31 19:21:41,544 : Best param found at split 4: l2reg = 0.25                 with score 85.46
# 2018-05-31 19:22:07,638 : Best param found at split 5: l2reg = 0.25                 with score 85.28
# 2018-05-31 19:22:33,747 : Best param found at split 6: l2reg = 0.25                 with score 85.41
# 2018-05-31 19:23:00,171 : Best param found at split 7: l2reg = 0.25                 with score 85.06
# 2018-05-31 19:23:25,303 : Best param found at split 8: l2reg = 0.25                 with score 85.42
# 2018-05-31 19:23:51,034 : Best param found at split 9: l2reg = 0.25                 with score 85.26
# 2018-05-31 19:24:16,632 : Best param found at split 10: l2reg = 0.25                 with score 84.95
# 2018-05-31 19:24:17,039 : Dev acc : 85.27 Test acc : 85.33
#
# 2018-05-31 19:24:17,044 : ***** Transfer task : SUBJ *****
#
#
# 2018-05-31 19:24:22,221 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:24:22,502 : Generating sentence embeddings
# 2018-05-31 19:24:23,163 : Generated sentence embeddings
# 2018-05-31 19:24:23,165 : Training sklearn-LogReg with (inner) 10-fold cross-validation
# 2018-05-31 19:24:49,449 : Best param found at split 1: l2reg = 0.25                 with score 85.24
# 2018-05-31 19:25:15,656 : Best param found at split 2: l2reg = 0.25                 with score 85.38
# 2018-05-31 19:25:41,938 : Best param found at split 3: l2reg = 0.5                 with score 85.4
# 2018-05-31 19:26:08,250 : Best param found at split 4: l2reg = 1                 with score 85.37
# 2018-05-31 19:26:34,422 : Best param found at split 5: l2reg = 0.25                 with score 85.19
# 2018-05-31 19:27:00,886 : Best param found at split 6: l2reg = 0.5                 with score 85.29
# 2018-05-31 19:27:27,489 : Best param found at split 7: l2reg = 0.25                 with score 85.23
# 2018-05-31 19:27:53,655 : Best param found at split 8: l2reg = 0.25                 with score 85.6
# 2018-05-31 19:28:19,777 : Best param found at split 9: l2reg = 0.5                 with score 85.32
# 2018-05-31 19:28:45,903 : Best param found at split 10: l2reg = 0.5                 with score 84.97
# 2018-05-31 19:28:46,252 : Dev acc : 85.3 Test acc : 85.27
#
# 2018-05-31 19:28:46,256 : ***** Transfer task : SST Binary classification *****
#
#
# 2018-05-31 19:28:51,570 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:28:51,828 : Computing embedding for test
# 2018-05-31 19:28:51,942 : Computed test embeddings
# 2018-05-31 19:28:51,943 : Computing embedding for dev
# 2018-05-31 19:28:52,070 : Computed dev embeddings
# 2018-05-31 19:28:52,072 : Computing embedding for train
# 2018-05-31 19:28:55,110 : Computed train embeddings
# 2018-05-31 19:28:55,111 : Training sklearn-LogReg with standard validation..
# 2018-05-31 19:29:11,962 : [('reg:0.25', 73.74), ('reg:0.5', 73.74), ('reg:1', 73.85), ('reg:2', 73.85), ('reg:4', 73.85), ('reg:8', 73.85)]
# 2018-05-31 19:29:11,963 : Validation : best param found is reg = 1 with score             73.85
# 2018-05-31 19:29:11,964 : Evaluating...
# 2018-05-31 19:29:14,719 :
# Dev acc : 73.85 Test acc : 72.98 for             SST Binary classification
#
# 2018-05-31 19:29:14,742 : ***** Transfer task : TREC *****
#
#
# 2018-05-31 19:29:19,845 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:29:20,402 : Computed train embeddings
# 2018-05-31 19:29:20,423 : Computed test embeddings
# 2018-05-31 19:29:20,425 : Training sklearn-LogReg with 10-fold cross-validation
# 2018-05-31 19:31:07,412 : [('reg:0.5', 63.37), ('reg:1', 63.17), ('reg:2', 62.76), ('reg:4', 62.6), ('reg:8', 62.45), ('reg:16', 62.38), ('reg:32', 62.36)]
# 2018-05-31 19:31:07,413 : Cross-validation : best param found is reg = 0.5             with score 63.37
# 2018-05-31 19:31:07,414 : Evaluating...
# 2018-05-31 19:31:08,809 :
# Dev acc : 63.37 Test acc : 62.4             for TREC
#
# 2018-05-31 19:31:08,812 : ***** Transfer task : MRPC *****
#
#
# 2018-05-31 19:31:13,887 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:31:14,128 : Computing embedding for test
# 2018-05-31 19:31:14,339 : Computed test embeddings
# 2018-05-31 19:31:14,340 : Computing embedding for train
# 2018-05-31 19:31:14,835 : Computed train embeddings
# 2018-05-31 19:31:14,879 : Training sklearn-LogReg with 10-fold cross-validation
# 2018-05-31 19:31:46,159 : [('reg:0.5', 70.49), ('reg:1', 70.17), ('reg:2', 70.22), ('reg:4', 70.44), ('reg:8', 69.85), ('reg:16', 69.19), ('reg:32', 68.55)]
# 2018-05-31 19:31:46,160 : Cross-validation : best param found is reg = 0.5             with score 70.49
# 2018-05-31 19:31:46,161 : Evaluating...
# 2018-05-31 19:31:46,430 : Dev acc : 70.49 Test acc 71.71; Test F1 81.22 for MRPC.
#
# 2018-05-31 19:31:46,436 : ***** Transfer task : SICK-Entailment*****
# 2018-05-31 19:31:51,537 : Found 70427 words with word vectors, out of         70427 words
# 2018-05-31 19:31:51,770 : Computing embedding for test
# 2018-05-31 19:31:52,187 : Computed test embeddings
# 2018-05-31 19:31:52,188 : Computing embedding for dev
# 2018-05-31 19:31:52,235 : Computed dev embeddings
# 2018-05-31 19:31:52,236 : Computing embedding for train
# 2018-05-31 19:31:52,615 : Computed train embeddings
# 2018-05-31 19:31:52,694 : Training sklearn-LogReg with standard validation..
# 2018-05-31 19:32:00,432 : [('reg:0.25', 67.8), ('reg:0.5', 67.6), ('reg:1', 68.2), ('reg:2', 67.2), ('reg:4', 68.2), ('reg:8', 67.4)]
# 2018-05-31 19:32:00,433 : Validation : best param found is reg = 1 with score             68.2
# 2018-05-31 19:32:00,434 : Evaluating...
# 2018-05-31 19:32:01,603 :
# Dev acc : 68.2 Test acc : 69.35 for                        SICK entailment
#
# 2018-05-31 19:32:01,617 : ***** Transfer task : STS14 *****
#
#
# 2018-05-31 19:32:06,708 : Found 70427 words with word vectors, out of         70427 words
# /Users/melissatjhia/Documents/jaar1ai/Unsupervised Language Learning/Assignment3/SentEval/senteval/utils.py:39: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
# 2018-05-31 19:32:07,025 : deft-forum : pearson = 0.4182, spearman = 0.4146
# 2018-05-31 19:32:07,089 : deft-news : pearson = 0.7385, spearman = 0.6872
# 2018-05-31 19:32:07,224 : headlines : pearson = 0.6277, spearman = 0.5944
# 2018-05-31 19:32:07,356 : images : pearson = 0.7636, spearman = 0.7311
# 2018-05-31 19:32:07,483 : OnWN : pearson = 0.7746, spearman = 0.7864
# 2018-05-31 19:32:07,621 : tweet-news : pearson = 0.6478, spearman = 0.5766
# 2018-05-31 19:32:07,623 : ALL (weighted average) : Pearson = 0.6720,             Spearman = 0.6424
# 2018-05-31 19:32:07,623 : ALL (average) : Pearson = 0.6617,             Spearman = 0.6317
# {'MRPC': {'ntest': 1725, 'acc': 71.71, 'f1': 81.22, 'ndev': 4076, 'devacc': 70.49}, 'SUBJ': {'ntest': 10000, 'acc': 85.27, 'ndev': 10000, 'devacc': 85.3}, 'SICKEntailment': {'ntest': 4927, 'acc': 69.35, 'ndev': 500, 'devacc': 68.2}, 'SST2': {'ntest': 1821, 'acc': 72.98, 'ndev': 872, 'devacc': 73.85}, 'TREC': {'ntest': 500, 'acc': 62.4, 'ndev': 5452, 'devacc': 63.37}, 'CR': {'ntest': 3775, 'acc': 75.55, 'ndev': 3775, 'devacc': 75.63}, 'MR': {'ntest': 10662, 'acc': 70.91, 'ndev': 10662, 'devacc': 71.0}, 'STS14': {'images': {'spearman': SpearmanrResult(correlation=0.731063787213996, pvalue=2.6200347805747797e-126), 'pearson': (0.7636180264787633, 2.941828355536969e-144), 'nsamples': 750}, 'all': {'spearman': {'mean': 0.6317067629922892, 'wmean': 0.6424190545421659}, 'pearson': {'mean': 0.6617292181491062, 'wmean': 0.6720056528400011}}, 'deft-news': {'spearman': SpearmanrResult(correlation=0.6871623024175811, pvalue=2.98346157189256e-43), 'pearson': (0.7384544393947768, 6.220629104998448e-53), 'nsamples': 300}, 'deft-forum': {'spearman': SpearmanrResult(correlation=0.4146198094808933, pvalue=4.0113916462362084e-20), 'pearson': (0.4181859526444162, 1.778862290290591e-20), 'nsamples': 450}, 'OnWN': {'spearman': SpearmanrResult(correlation=0.7863501835186212, pvalue=1.2975480835743776e-158), 'pearson': (0.774592485315249, 5.603435266068429e-151), 'nsamples': 750}, 'headlines': {'spearman': SpearmanrResult(correlation=0.594433914153942, pvalue=7.578392147642133e-73), 'pearson': (0.6276891323829948, 2.0543649504620204e-83), 'nsamples': 750}, 'tweet-news': {'spearman': SpearmanrResult(correlation=0.576610581168702, pvalue=1.1285116240432418e-67), 'pearson': (0.6478352726784375, 1.8251206339906114e-90), 'nsamples': 750}}, 'MPQA': {'ntest': 10606, 'acc': 85.33, 'ndev': 10606, 'devacc': 85.27}}
